# %%
import warnings
warnings.filterwarnings("ignore")
# %env TOKENIZERS_PARALLELISM=true
# Out:
# env: TOKENIZERS_PARALLELISM=true

# %%
from openai import OpenAI

from helper import RAGChatWidget, SimpleVectorDB
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 from openai import OpenAI
# ----> 3 from helper import RAGChatWidget, SimpleVectorDB
#
# File ~/Desktop/Anshu/Generative_AI/Guardrails/L1/helper.py:9
#       7 from guardrails import Guard, settings
#       8 from IPython.display import display
# ----> 9 from sentence_transformers import SentenceTransformer
#      11 # these expect to find a .env file at the directory above the lesson.
#      12 # the format for that file is (without the comment)#API_KEYNAME=AStringThatIsTheLongAPIKeyFromSomeService
#      15 def load_env():
#
# ModuleNotFoundError: No module named 'sentence_transformers'
